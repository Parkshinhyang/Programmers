# %% [markdown]
# <a href="https://colab.research.google.com/github/Parkshinhyang/Programmers/blob/main/%EC%9A%94%EA%B2%A9_%EC%8B%9C%EC%8A%A4%ED%85%9C(Lv_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 문제 - 요격 시스템
# [문제 링크](https://school.programmers.co.kr/learn/courses/30/lessons/181188)
#
# ## 문제 설명
#
# A 나라가 B 나라를 침공하였습니다. B 나라의 대부분의 전략 자원은 아이기스 군사 기지에 집중되어 있기 때문에 A 나라는 B 나라의 아이기스 군사 기지에 융단폭격을 가했습니다.
#
# A 나라의 공격에 대항하여 아이기스 군사 기지에서는 무수히 쏟아지는 폭격 미사일들을 요격하려고 합니다. 이곳에는 백발백중을 자랑하는 요격 시스템이 있지만 운용 비용이 상당하기 때문에 미사일을 최소로 사용해서 모든 폭격 미사일을 요격하려 합니다.
#
# A 나라와 B 나라가 싸우고 있는 이 세계는 2 차원 공간으로 이루어져 있습니다. A 나라가 발사한 폭격 미사일은 x 축에 평행한 직선 형태의 모양이며 개구간을 나타내는 정수 쌍 (s, e) 형태로 표현됩니다. B 나라는 특정 x 좌표에서 y 축에 수평이 되도록 미사일을 발사하며, 발사된 미사일은 해당 x 좌표에 걸쳐있는 모든 폭격 미사일을 관통하여 한 번에 요격할 수 있습니다. 단, 개구간 (s, e)로 표현되는 폭격 미사일은 s와 e에서 발사하는 요격 미사일로는 요격할 수 없습니다. 요격 미사일은 실수인 x 좌표에서도 발사할 수 있습니다.
# 각 폭격 미사일의 x 좌표 범위 목록 targets이 매개변수로 주어질 때, 모든 폭격 미사일을 요격하기 위해 필요한 요격 미사일 수의 최솟값을 return 하도록 solution 함수를 완성해 주세요.
#
# ## 제한 사항
# - 1 ≤ targets의 길이 ≤ 500,000
# - targets의 각 행은 [s,e] 형태입니다.
#     - 이는 한 폭격 미사일의 x 좌표 범위를 나타내며, 개구간 (s, e)에서 요격해야 합니다.
#     - 0 ≤ s < e ≤ 100,000,000
#
# ## 입출력 예
#
# ![image.png](data:image/png;base64,...)
#
# ## 입출력 예 설명
#
# ![image.png](data:image/png;base64,...)
#
# 위 그림과 같이 최소 세 번의 요격 미사일 발사로 전부 방어할 수 있습니다.

# %% [markdown]
# ## 첫 번째 방법
#
# 1. 두 폭격 미사일의 범위를 비교해 겹치는 부분을 반환해주는 함수 overlap을 선언.
# 2. [s, e]형태의 원소 집합인 targets을 e를 기준으로 오름차순 정렬.
# 3. s1에 targets[0]을 저장.
# 4. targets의 첫 번째 원소부터 순회하는 반복문으로 s1과 target[i]을 overlap함수로 비교해 s1에 저장하고 s1이 비어있으면 즉, 겹치는 부분이 없으면 answer을 카운트하고 s1에 targets[i]를 저장.
# 5. answer을 return.
#
# 결과 : 성공

# %%
def overlap(x, y):
    if x[1] <= y[0]:
        return []
    return [max(x[0], y[0]), min(x[1], y[1])]
    
def solution(targets):
    answer = 1
    targets.sort(key = lambda x : x[1])
    s1 = targets[0]

    for i in range(1, len(targets)):
        s1 =  overlap(s1, targets[i])
        if not s1:
            answer += 1
            s1 = targets[i]
    return answer

solution([[4,5],[4,8],[10,14],[11,13],[5,12],[3,7],[1,4]])
# Out:
# 3
