# %% [markdown]
# <a href="https://colab.research.google.com/github/Parkshinhyang/Programmers/blob/main/n%5E2_%EB%B0%B0%EC%97%B4_%EC%9E%90%EB%A5%B4%EA%B8%B0(Lv_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 문제 - n^2 배열 자르기
#
# [문제 링크](https://school.programmers.co.kr/learn/courses/30/lessons/87390)
#
# ## 문제 설명
#
# 정수 n, left, right가 주어집니다. 다음 과정을 거쳐서 1차원 배열을 만들고자 합니다.
#
# 1. n행 n열 크기의 비어있는 2차원 배열을 만듭니다.
# 2. i = 1, 2, 3, ..., n에 대해서, 다음 과정을 반복합니다.
#     - 1행 1열부터 i행 i열까지의 영역 내의 모든 빈 칸을 숫자 i로 채웁니다.
# 3. 1행, 2행, ..., n행을 잘라내어 모두 이어붙인 새로운 1차원 배열을 만듭니다.
# 4. 새로운 1차원 배열을 arr이라 할 때, arr[left], arr[left+1], ..., arr[right]만 남기고 나머지는 지웁니다.
#
# 정수 n, left, right가 매개변수로 주어집니다. 주어진 과정대로 만들어진 1차원 배열을 return 하도록 solution 함수를 완성해주세요.
#
# ## 제한사항
#
# - 1 ≤ n ≤ 107
# - 0 ≤ left ≤ right < n2
# - right - left < 105
#
# ## 입출력 예
#
# ![image.png](data:image/png;base64,...)
#
# ## 입출력 예 설명
#
# ### 입출력 예 #1
#
# - 다음 애니메이션은 주어진 과정대로 1차원 배열을 만드는 과정을 나타낸 것입니다.
#
# ![FlattenedFills_ex1.gif](data:image/gif;base64,...)
#
# ### 입출력 예 #2
#
# - 다음 애니메이션은 주어진 과정대로 1차원 배열을 만드는 과정을 나타낸 것입니다.
#
# ![FlattenedFills_ex2.gif](data:image/gif;base64,...)

# %% [markdown]
# ## 첫 번째 방법
#
# 1. n x n만큼 0으로 초기화된 2차 행렬 answer 선언.
# 2. answer을 모두 탐색해 2차 행렬 인덱스 중 큰 수의 + 1한 값을 저장.
# 3. res에 answer을 행마다 잘라붙이고 주어진 조건만큼 슬라이싱하여 return.
#
# 결과 : 실패

# %%
def solution(n, left, right):
    answer = [[0 for _ in range(n)] for _ in range(n)]
    res = []
    for i in range(n):
        for j in range(n):
            answer[i][j] = max(i, j) + 1
    for ans in answer:
        res += ans
    print(res)
    return res[left : right + 1]
solution(4, 7, 14)
# Out:
# [1, 2, 3, 4, 2, 2, 3, 4, 3, 3, 3, 4, 4, 4, 4, 4]
# [4, 3, 3, 3, 4, 4, 4, 4]

# %% [markdown]
# ## 두 번째 방법
#
# 1. 첫 번째 방법처럼 모든 배열을 다 구하여 슬라이싱 하는 방법이 아니라 left부터 right까지의 수만 구하는 방식을 사용.
# 2. left부터 right + 1까지 반복하는 반복문으로 answer에 i // n과 i % n 중 더 큰 값에 1을 더한 값을 append후 answer을 return.
#
# 결과 : 성공

# %%
def solution(n, left, right):
    answer = []
    
    for i in range(left, right + 1):
        answer.append(max(i // n, i % n) + 1)
    return answer
solution(3, 2, 5)
# Out:
# [3, 2, 2, 3]
